# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/mnist-gan/train.py \
        --data_dir /content/drive/MyDrive/mnist-gan/data \
        --result_dir /content/drive/MyDrive/mnist-gan/result_dir \
        --ckpt_dir /content/drive/MyDrive/mnist-gan/checkpoint
# Out:
# epoch: 0, loss_G:1.4596450835466386, loss_D:0.5069215333461762
# epoch: 0, loss_G:1.3469103302061558, loss_D:0.5451647825539112
# epoch: 0, loss_G:1.3054254534343879, loss_D:0.5523839116096496
# epoch: 0, loss_G:1.2796190902590752, loss_D:0.5513624004274607
# epoch: 0, loss_G:1.2898548170328141, loss_D:0.5560418235063553
# epoch: 0, loss_G:1.2656295472383499, loss_D:0.5635233930250009
# epoch: 0, loss_G:1.244150463363954, loss_D:0.5706189867428371
# epoch: 0, loss_G:1.2231867831386625, loss_D:0.5771285998076201
# epoch: 0, loss_G:1.2041935142046876, loss_D:0.5837775532735718
# epoch: 0, loss_G:1.1875060768723489, loss_D:0.5898774153292179
# epoch: 0, loss_G:1.1682142676819454, loss_D:0.5946262517029589
# epoch: 0, loss_G:1.1509136274953684, loss_D:0.5992367072155078
# epoch: 0, loss_G:1.1356742258943044, loss_D:0.6033551491453097
# epoch: 0, loss_G:1.1200175859459809, loss_D:0.607860976010561
# epoch: 0, loss_G:1.103002280294895, loss_D:0.6112554141084353
# ...
