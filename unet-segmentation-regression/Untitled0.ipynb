# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd /content/drive/MyDrive/unet-segmentation-regression

# %%
# !ls /content/drive/MyDrive/unet-segmentation-regression/data/BSR/BSDS500/data/images/train
# Out:
# 100075.jpg  145014.jpg	187003.jpg  238011.jpg	310007.jpg  46076.jpg
# 100080.jpg  145053.jpg	187029.jpg  239007.jpg	311068.jpg  48055.jpg
# 100098.jpg  147021.jpg	187039.jpg  239096.jpg	311081.jpg  54005.jpg
# 103041.jpg  147062.jpg	187071.jpg  24004.jpg	314016.jpg  55067.jpg
# 104022.jpg  15004.jpg	187083.jpg  24063.jpg	317080.jpg  55075.jpg
# 105019.jpg  15088.jpg	188005.jpg  242078.jpg	323016.jpg  56028.jpg
# 105053.jpg  151087.jpg	188063.jpg  245051.jpg	326038.jpg  59078.jpg
# 106020.jpg  153077.jpg	188091.jpg  246016.jpg	33066.jpg   60079.jpg
# 106025.jpg  153093.jpg	189003.jpg  246053.jpg	35008.jpg   61060.jpg
# 108041.jpg  155060.jpg	189011.jpg  247085.jpg	35010.jpg   61086.jpg
# 108073.jpg  156079.jpg	196015.jpg  249061.jpg	35058.jpg   65010.jpg
# 109034.jpg  157036.jpg	198004.jpg  249087.jpg	35070.jpg   65019.jpg
# 112082.jpg  159029.jpg	198023.jpg  25098.jpg	35091.jpg   65074.jpg
# 113009.jpg  159045.jpg	198054.jpg  253036.jpg	353013.jpg  65132.jpg
# ...

# %%
# !python /content/drive/MyDrive/unet-segmentation-regression/train.py \
        --data_dir /content/drive/MyDrive/unet-segmentation-regression/data/BSR/BSDS500/data/images \
        --ckpt_dir /content/drive/MyDrive/unet-segmentation-regression/checkpoint \
        --log_dir /content/drive/MyDrive/unet-segmentation-regression/log \
        --result_dir /content/drive/MyDrive/unet-segmentation-regression/result \
        --opts 'random' 90.0
# Out:
# Namespace(batch_size=4, ckpt_dir='/content/drive/MyDrive/unet-segmentation-regression/checkpoint', data_dir='/content/drive/MyDrive/unet-segmentation-regression/data/BSR/BSDS500/data/images', learning_type='plain', log_dir='/content/drive/MyDrive/unet-segmentation-regression/log', lr=0.001, mode='train', nch=3, network='unet', nkernel=64, num_epoch=50, nx=480, ny=320, opts=['random', '90.0'], result_dir='/content/drive/MyDrive/unet-segmentation-regression/result', task='denoising', train_continue='off')
# ...
