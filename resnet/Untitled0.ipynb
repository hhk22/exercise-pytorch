# %%
# !python /content/drive/MyDrive/resnet/train.py \
        --data_dir /content/drive/MyDrive/resnet/data/BSR/BSDS500/data/images \
        --ckpt_dir /content/drive/MyDrive/resnet/checkpoint \
        --log_dir /content/drive/MyDrive/resnet/log \
        --result_dir /content/drive/MyDrive/resnet/result

# %%
# !python /content/drive/MyDrive/resnet/train.py \
        --data_dir /content/drive/MyDrive/resnet/data/BSR/BSDS500/data/images \
        --ckpt_dir /content/drive/MyDrive/resnet/checkpoint \
        --log_dir /content/drive/MyDrive/resnet/log \
        --result_dir /content/drive/MyDrive/resnet/result
# Out:
# TRAIN EPOCH:0, BATCH:10, LOSS:0.186
# TRAIN EPOCH:0, BATCH:20, LOSS:0.145
# TRAIN EPOCH:0, BATCH:30, LOSS:0.120
# TRAIN EPOCH:0, BATCH:40, LOSS:0.103
# TRAIN EPOCH:0, BATCH:50, LOSS:0.092
# VAL EPOCH:0, BATCH:1, LOSS:0.028
# VAL EPOCH:0, BATCH:2, LOSS:0.038
# VAL EPOCH:0, BATCH:3, LOSS:0.039
# VAL EPOCH:0, BATCH:4, LOSS:0.042
# VAL EPOCH:0, BATCH:5, LOSS:0.042
# VAL EPOCH:0, BATCH:6, LOSS:0.043
# VAL EPOCH:0, BATCH:7, LOSS:0.042
# VAL EPOCH:0, BATCH:8, LOSS:0.043
# VAL EPOCH:0, BATCH:9, LOSS:0.044
# VAL EPOCH:0, BATCH:10, LOSS:0.043
# VAL EPOCH:0, BATCH:11, LOSS:0.042
# VAL EPOCH:0, BATCH:12, LOSS:0.043
# VAL EPOCH:0, BATCH:13, LOSS:0.041
# VAL EPOCH:0, BATCH:14, LOSS:0.040
# VAL EPOCH:0, BATCH:15, LOSS:0.040
# VAL EPOCH:0, BATCH:16, LOSS:0.041
# VAL EPOCH:0, BATCH:17, LOSS:0.040
# VAL EPOCH:0, BATCH:18, LOSS:0.041
# VAL EPOCH:0, BATCH:19, LOSS:0.041
# VAL EPOCH:0, BATCH:20, LOSS:0.040
# VAL EPOCH:0, BATCH:21, LOSS:0.041
# VAL EPOCH:0, BATCH:22, LOSS:0.041
# ...
