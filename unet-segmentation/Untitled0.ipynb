# %%
# %load_ext tensorboard

# %%
tensorboard --log_dir='content/drive/MyDrive/unet-segmentation-new/log'
# Out:
# ERROR: Failed to launch TensorBoard (exited with 1).
# Contents of stderr:
# Error: A logdir or db must be specified. For example `tensorboard --logdir mylogdir` or `tensorboard --db sqlite:~/.tensorboard.db`. Run `tensorboard --helpfull` for details and examples.

# %%
# !python3 "/content/drive/MyDrive/unet-segmentation-new/train.py" \
--lr 1e-2 --batch_size 4 --num_epoch 100 \
--data_dir "/content/drive/MyDrive/unet-segmentation-new/data" \
--ckpt_dir "/content/drive/MyDrive/unet-segmentation-new/checkpoint" \
--log_dir "/content/drive/MyDrive/unet-segmentation-new/log" \
--mode "train" \
--train_continue "off"
# Out:
# Namespace(batch_size=2, ckpt_dir='/content/drive/MyDrive/unet-segmentation-new/checkpoint', data_dir='/content/drive/MyDrive/unet-segmentation-new/data', log_dir='/content/drive/MyDrive/unet-segmentation-new/log', lr=0.01, mode='train', num_epoch=100, result_dir='./result', train_continue='off')
# batch : 0
# batch : 1
# batch : 2
# batch : 3
# batch : 4
# batch : 5
# batch : 6
# batch : 7
# batch : 8
# batch : 9
# batch : 10
# batch : 11
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/unet-segmentation-new/train.py", line 149, in <module>
#     writer_train.add_scalar('loss', np.mean(loss_arr), epoch)
#   File "<__array_function__ internals>", line 6, in mean
#   File "/usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py", line 3438, in mean
#     return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# TypeError: mean() received an invalid combination of arguments - got (out=NoneType, axis=NoneType, dtype=NoneType, ), but expected one of:
# ...
